# %%
from src.utils.constants import get_repo_folder
import pandas as pd

repo_folder = get_repo_folder()
print(f"Repository folder: {repo_folder}")

hqa_path = repo_folder / "src/data/DB_questions/History/HQA-data/hqa_train_df.csv"

# show head of each train_data.csv file
hqa_df = pd.read_csv(hqa_path)
# shuffle the dataframe
hqa_df = hqa_df.sample(frac=1).reset_index(drop=True)
hqa_df.head(20)
# Out:
# Repository folder: /data/home/gkeren/PrivateTeacherAgent
#     dialogueID                                            Context  \
# 0   264377.tsv  I know how to add them though Nice! :) they so...
# 1   261983.tsv   mine can export to a file on the sd card.. No...
# 2   265924.tsv  Or right-click the desktop and click 'Open Ter...
# 3    26260.tsv  thx what lutz said works better, my way was ki...
# 4   264354.tsv  I've downloaded the AMD64 iso by mistake on 56...
# 5   102265.tsv  I just downloaded vmware server rpm file. how ...
# 6   265824.tsv  -> did yuo try with 'Wine' ..? Wine is a progr...
# 7   105466.tsv  how can I upgrade openoffice to v3? how can I ...
# 8   262887.tsv  <akonkwa> it should be automatic when you plug...
# 9   260649.tsv  whats a good cd/dvd program for burning ? k3b ...
# 10  265601.tsv  you guys, this isnt meant to switch you over, ...
# 11  264490.tsv  Help me guys... I try to install feisty server...
# 12  263451.tsv  any quick way to find out how many packages th...
# 13  264608.tsv   /join #5,0!  /join #5,0 or rather, don't. I'm...
# 14  100399.tsv  I've a problem. apt-get, man, aptitude and oth...
# 15  266533.tsv  what is the relationship between debian an ubu...
# 16  231654.tsv  I agree Im not very techie I would call myself...
# 17  105386.tsv  how do i archive a file with tar? tar -cvvf ar...
# 18  265638.tsv   i dont how to compile c program plz dont mind...
# 19  261040.tsv  can someone tell me why my firefox think 1.0.7...
#
#       QuestionID                                           Question  \
# 0   264377.tsv_3  What is the command to open the starbar like t...
# 1   261983.tsv_4  What app would i suggest finding in #android w...
# 2   265924.tsv_2   How can we switch from developmental release to?
# 3    26260.tsv_1                    What did lutz say works better?
# 4   264354.tsv_2      Is there any way to that I may download what?
# 5   102265.tsv_1                     What file did I just download?
# 6   265824.tsv_1                             Who tried with 'Wine'?
# 7   105466.tsv_4                     What is sudo's first question?
# 8   262887.tsv_1           What happens if akonkwa doesn't show up?
# 9   260649.tsv_5      What will cause this kind of stuff to happen?
# 10  265601.tsv_2  Where do you want to try a 100% working versio...
# 11  264490.tsv_5                          Where do i open a window?
# 12  263451.tsv_6                                What does kde work?
# 13  264608.tsv_3  What is the size of the monitor I'm stuck in w...
# 14  100399.tsv_3                          What is a broadcast ping?
# 15  266533.tsv_1  What is the relationship between debian and ub...
# 16  231654.tsv_5                          What does ubuntu support?
# 17  105386.tsv_4  What packages are in place right click throws ...
# 18  265638.tsv_2   What is a gui with the server version of Ubuntu?
# 19  261040.tsv_3                         What does warthog install?
#
#                                                Answer  Answer Start  \
# 0                                         ctrl-alt-F2           282
# 1                                       3rd party app           423
# 2                                      stable release           195
# 3                             sudo ls -Ralh /dev/disk            71
# 4                                       certail files            96
# 5                                   vmware server rpm            18
# 6                                                 yuo             7
# 7                       how can i add myself to wheel          1202
# 8                               if it doesn't show up            63
# 9                                             windows           122
# 10                                             ubuntu            53
# 11                                   ubuntus nautilus           251
# 12                            when other one does not           335
# 13                                               60hz            55
# 14                                       ping request           761
# 15  what is the relationship between debian an ubuntu             0
# 16                                     wireless cards           464
# 17                                   ark, unrar, etc.          1347
# 18                           not installed by default           390
# 19                                        win32codecs           276
#
#     Answer End
# 0          293
# 1          436
# 2          209
# 3           94
# 4          109
# 5           35
# 6           10
# 7         1231
# 8           84
# 9          129
# 10          59
# 11         267
# 12         358
# 13          59
# 14         773
# 15          49
# 16         478
# 17        1363
# 18         414
# 19         287

# %%
def format_text(text, n=100):
    # if its too long than n characters, split it into lines of n characters
    if len(text) > n:
        return '\n'.join(text[i:i+n] for i in range(0, len(text), n))
    return text

for index in range(5):
    # print for the first row the context, question, and answer. 
    print(f"Context: {format_text(hqa_df['Context'][index])}")
    print(f"Question: {format_text(hqa_df['Question'][index])}")
    print(f"Answer: {format_text(hqa_df['Answer'][index])}")
    print("-" * 50)
# Out:
# Context: I know how to add them though Nice! :) they sound like suppositories only they don't hurt your anus
# ok my other stupid question for the nite, is.. how the frig do u operate kde without a mouse.. whats
#  the command to open the starbar like thing windows key isnt working the console? ctrl-alt-F2
# Question: What is the command to open the starbar like thing windows key isnt working the console?
# Answer: ctrl-alt-F2
# --------------------------------------------------
# Context:  mine can export to a file on the sd card.. Not sure about what else other then android can import t
# hem.. You an also export them all to  you gmail account I think. the problem is, all guides I can fi
# nd online refer to menus and options that I cannot see on my friend's phone  for mine. I just went t
# o the phone/contacts and ther ewas a export.. in the menus.. possible its not on the phone. So i wou
# ld suggest finding some 3rd party app. and asking in #android while in the process of installing bre
# ezy badger last night.. my install bombed out just before it could install a boot loader.. how do i
# go about installing grub manually? seveas: what would be the best way to boot into the operating sys
# tem, w/o grub installed live cd with grub hmm, no idea actually
# Question: What app would i suggest finding in #android while in the process of installing breezy badger?
# Answer: 3rd party app
# --------------------------------------------------
# Context: Or right-click the desktop and click 'Open Terminal' 'what is sure, is that maybe' is the end of tha
# t saying I believe ;) Well, it's another saying. can we switch from `developmental release' to stabl
# e release? if i download karmic koala can i switch to stable when it gets released? which kernel doe
# s karmic koala have? #ubuntu+1 for karmic questions, please
# Question: How can we switch from developmental release to?
# Answer: stable release
# --------------------------------------------------
# Context: thx what lutz said works better, my way was kinda a joke but works too sudo ls -Ralh /dev/disk If i
# dual boot with windows, with 3 partitions, one being the Windows NTFS, the other being the Ubuntu FA
# T32, the 3rd being swapspace, do i have to set any partition with a bootable flag? If i dual boot wi
# th windows, with 3 partitions, one being the Windows NTFS, the other being the Ubuntu FAT32, the 3rd
#  being swapspace, do i have to set any partition with a bootable flag? and also, if i don't want to
# install GRUB to the MBR, how do i make it to install to a floppy disk. smock, apt-get is a terminal
# command The rest are for use with the GUI, Synaptic is just a frontend to apt as far as I know, yes
# but i've only been working off the live cd. i myself am not completely sure of the difference betwee
# n Add Apps and Synaptic. they are basically the same thing. Linux has many ways of doing the same th
# ing I find about the floopy part...I use floppy myself as it seesm the easiest solution to my situat
# ion. when it asks to install grub in mbr say no and it will ask where and give probably something li
# ke fd0 as an example of where to point install. I used /dev/fd0 and it worked for me I think you mea
# n the fat 32 is setup and you want to use the space for ubuntu...? well pretty much, i've tried to i
# nstall Ubuntu many times. At first, i only had one NTFS partiton for windows. I eventually resized t
# he NTFS and created a FAT 32 partition for Ubuntu using the installer. So it created the partition,
# then it quit with a debootstrap error. After trying everything everyone's told me, i was finally tol
# d to get another cd. It arrived a couple of weeks... hmm...in my situation i got myself a new 250gb
# hdd and used the setup cd to partition the drive fore windows and left about 12gb for ubuntu (unallo
# cated). I then used the install cd'd automatic partitioning to set up the free space and installed g
# rub on floppy. I think a seperate drive is usually easiest for install if you can afford it how big
# is the drive? hello i.m a newer hi! do you need any help related to ubuntu? 您可以访问中文频道：打字  /join #ubu
# ntu-cn can you type? type /join #ubuntu-cn :) hi! isn't there an acroread package for feisty? yes an
# d.... where? go to system->administration->synaptic package manager and search for acroread, you can
#  install it there i'm actually on kde, but not even apt-cache search returns anything for acroread o
# h, you need to enable another repository, just a sec i have universe and multiverse enabled i think
# it's in the medibuntu repository, lemme find more info thanks for your support yeah, medibuntu, here
# 's the line I have in /etc/apt/sources.list (or /etc/apt/sources.list.d/ folder): deb http://package
# s.medibuntu.org/ feisty free non-free thank you! first off: is there a way to disable DMA? I know th
# at my mobo freaks out giving SQUASHFS errors if it's own (learned from trying to install gentoo) It'
# s okay, I'm just really tired of failing I can't get ANYTHING to install on this server it doesn't m
# atter which HD or anything it just doesn't work This is the i386 version The computer I'm trying to
# install on is a dual processor HP e 800 server. Every OS I've tried to install, XP, Ubuntu, Gentoo h
# as failed. I just want a bash shell and aptitude and how did gentoo fail? does any livecd work? you
# have set it to boot off the harddisk in the bios right... nope, should be fine unless you're somehow
#  replacing a i386 with a powerpc one...somehow anyone using intel x3100 with an external monitor? ca
# n't get the proper resolution. what video card are you using? intel gma 965, x3100 my monitor expect
# s 1280x1024@60Hz and gets it, but the image is cropped to the left and partly blurry I heard you the
#  first time, I don't know what to tell you back up your xorg.conf and run sudo dpkg-reconfigure xser
# ver-xorg i'm still using the live cd. does this work though? it should? brb sudo dpkg-reconfigure do
# es not change anything related to my graphics settings. it's just asking for keyboard layout. no i d
# ont think its for windows I guess grub is for linux isn't it? no ok thanks miraj anyway no scunizi u
# buntu does not work either so what should i do scunizi ? I even inserted win 7 recovery cd but didno
# t boot from there anybody please hi I have dual boot win7 and ubuntu 12.4 I needed to reinstall win
# 7 (Alt+F10) recovery partition but it just came up with this error :no such partition I realy need m
# y laptop please if you know how i can solve this issue help me hi I have dual boot win7 and ubuntu 1
# 2.4 I needed to reinstall win 7 (Alt+F10) recovery partition but it just came up with this error :no
#  such partition What is 'it'? Your Windows? what do you use to photo edit? gimp its probably a bad q
# uestion but have you ever tried to get adobe cs2 running under ubuntu not a bad question but no, I t
# hink gimp is actually better than Photoshop. i cant comment but it wouldnt suprise me but unfortunat
# ely i have to receive files from designers who use photoshop but want to run ubuntu ubuntu opens PSD
#  files just fine with gimp I get PSD from people all the time do you find you have any formatting pr
# oblems - where they position one thing different from how you receive it no, I never had that issue,
#  PSD files get imported correctly do you mind if i pm you as this is slightly off topic go to #gimp
# just joined - thanks hi, I'm on Karmic, Having bluetooth problems, the gnome bluetooth manager can't
#  find my phone & vice versa. I think I've searched the whole net to no avail. there's no any /etc/bl
# uetooth/hcid.conf available on my system. any idea? what model are you using? for you bluetooth hard
# ware. It's a bluetooth bungle called 'mini NOVR e-blue' I am sorry I was not able to find any inform
# ation on your issue. I also do not have the knowledge to trouble shoot bluetooth on ubuntu. You are
# right there isn't anything on the net about it;that I could see at least. I appreciate your try, man
# y thanks ;) Hi. In short: gdm is broken. Details: after booting the login screen is not displayed, i
# nstead a blank (black) screen with a cryptic error dialogue (all characters of the message are squar
# es, same with OK button). I have compared my `/etc/gdm/gdm.conf' and `/etc/gdm/gdm.conf-custom' with
#  ones from a working machine, they are identical. I have attempted to run `gdm restart' - same resul
# t. `killall gdm' followed by `gdm start' - same result. Any help ﻿Kr0ntab: it was working yesterday
# evening, after installing coq/coqide and reconfiguring some of its shortkeys i left the computer on,
#  power outage during the night, today booted the computer and result as i described I recommend: apt
# -get --purge remove gdm; apt-get install gdm; dpkg-reconfigure -phigh xserver-xorg --purge is the ke
# y since it will not preserve loacl modification to config files. & all: well i did a reinstall of gd
# m, did a xserver reconfig and once again my consoles are gone Can you by any chance get hold of /var
# /log/Xorg.0.log and put it on pastebin? Ouch, well it would be helpfull :) histo: heres the Xorg.0.l
# og: http://paste.ubuntu.com/61749/ Hmm, it looks perfectly fine, I am without answers. memcache and
# what would be the magic question performance boost from storing quite a few objects and if will reac
# h a point where it will exceed memcache's capabilities that didn't answer my question but yes there
# is a limit when you run out of ram hence the function of memcache so if I'm seeing a 25% reduction i
# n memory usage would I continue to see that as my project scales up? memcache and what would be the
# magic question php ? yes how do i mount an .iso when i don't have a physical cdrom attached at the m
# oment? mount -o loop file.iso /mnt/ i keep getting mount: special device /dev/scd0 does not exist Wh
# at exact command are you using? got it got er :) dunno, trying to pass -t udf !gpg | jason !gprerr |
#  jasono !gpgerr thank you?
# Question: What did lutz say works better?
# Answer: sudo ls -Ralh /dev/disk
# --------------------------------------------------
# Context: I've downloaded the AMD64 iso by mistake on 56k dialup. Is there any way to that I may download cert
# ail files and replace them in the iso for my x86? would love some cd's   took a few days to d/l regi
# ster your nick first. you can't send Quintin a PM if you don't register. could someone point me to d
# ocumentation on how to manually install a network driver? What is teh default root password for the
# preview edition nothing better yes, 'sudo <any-command>', then give your own password
# Question: Is there any way to that I may download what?
# Answer: certail files
# --------------------------------------------------

# %% [markdown]
# we can see that the context is very long, we won't use it, but only the question answer pairs
