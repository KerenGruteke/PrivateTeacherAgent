# %%
from src.utils.constants import get_repo_folder
import json
import pandas as pd

repo_folder = get_repo_folder()
print(f"Repository folder: {repo_folder}")

chr_america_path = repo_folder / "src/data/DB_questions/History/ChroniclingAmericaQA/train.json"
print(chr_america_path)

with open(chr_america_path, "r") as f:
    data = json.load(f)  # loads the full list of dicts

df = pd.DataFrame(data)
df.head()
# Out:
# Repository folder: /data/home/gkeren/PrivateTeacherAgent
# /data/home/gkeren/PrivateTeacherAgent/src/data/DB_questions/History/ChroniclingAmericaQA/train.json
#   query_id                                           question         answer  \
# 0  train_1  Who is the author of the book, "Horrors of Sla...    WILLIAM RAY
# 1  train_2  Who was the Grand Officer of the Legion of Honor?   de Rosemberg
# 2  train_3  What country was Gen. de Rosemberg formerly Ma...         France
# 3  train_4          What was the title of Rev. Joseph McKean?   de Rosemberg
# 4  train_5  Who was the wife of Mr. Spencer L. at Westmore...  Sally Lincoln
#
#       org_answer                   para_id  \
# 0    WILLIAM RAY  New_Hampshire_18070804_1
# 1   de Rosemberg  New_Hampshire_18070804_4
# 2         France  New_Hampshire_18070804_4
# 3   de Rosemberg  New_Hampshire_18070804_4
# 4  Sally Lincoln  New_Hampshire_18070804_5
#
#                                              context  \
# 0  Aiscellaneous Repository. From the Albany Regi...
# 1  Surely he above the rest of his fellow mortals...
# 2  Surely he above the rest of his fellow mortals...
# 3  Surely he above the rest of his fellow mortals...
# 4  At Westmoreland, Mrs. Sally Lincoln, wife of M...
#
#                                              raw_ocr publication_date  \
# 0  fAiscellancous Bepogitory.\n. dvom the Albany ...       1807-08-04
# 1  Surely he a\nbove the rest of his fellow morta...       1807-08-04
# 2  Surely he a\nbove the rest of his fellow morta...       1807-08-04
# 3  Surely he a\nbove the rest of his fellow morta...       1807-08-04
# 4  At Weltmoreland, Mrs. Sally Liacoln, wife\n~of...       1807-08-04
#
#   trans_que trans_ans                                                url
# 0         0         0  https://chroniclingamerica.loc.gov/lccn/sn8302...
# 1         0         0  https://chroniclingamerica.loc.gov/lccn/sn8302...
# 2         0         0  https://chroniclingamerica.loc.gov/lccn/sn8302...
# 3         0         0  https://chroniclingamerica.loc.gov/lccn/sn8302...
# 4         0         0  https://chroniclingamerica.loc.gov/lccn/sn8302...
